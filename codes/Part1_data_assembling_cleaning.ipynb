# %% [markdown]
# ## To do
# * Data assembling
# * Data Cleaning

# %%
import pandas as pd

# %%
pd.read_csv('data/player_names.csv').head(1)
# Out:
#        id first_name last_name
# 0  452657        Jon    Lester

# %%
pd.read_csv('data/player_names.csv')[pd.read_csv('data/player_names.csv')['last_name'] == 'Scherzer']
# Out:
#         id first_name last_name
# 69  453286        Max  Scherzer

# %%
df = pd.read_csv('data/pitches.csv')

# %%
df = pd.concat([df,pd.read_csv('data/2019_pitches.csv')])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3595944 entries, 0 to 728789
# Data columns (total 40 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   px               float64
#  1   pz               float64
#  2   start_speed      float64
#  3   end_speed        float64
#  4   spin_rate        object
#  5   spin_dir         object
#  6   break_angle      float64
#  7   break_length     float64
#  8   break_y          float64
#  9   ax               float64
#  10  ay               float64
#  11  az               float64
#  12  sz_bot           float64
#  13  sz_top           float64
#  14  type_confidence  object
#  15  vx0              float64
#  16  vy0              float64
#  17  vz0              float64
#  18  x                object
#  19  x0               float64
#  20  y                object
#  21  y0               float64
#  22  z0               float64
#  23  pfx_x            float64
#  24  pfx_z            float64
# ...

# %%
df = pd.merge(df,pd.concat([pd.read_csv('data/atbats.csv'),pd.read_csv('data/2019_atbats.csv')]),on='ab_id')

# %%
df.columns
# Out:
# Index(['px', 'pz', 'start_speed', 'end_speed', 'spin_rate', 'spin_dir',
#        'break_angle', 'break_length', 'break_y', 'ax', 'ay', 'az', 'sz_bot',
#        'sz_top', 'type_confidence', 'vx0', 'vy0', 'vz0', 'x', 'x0', 'y', 'y0',
#        'z0', 'pfx_x', 'pfx_z', 'nasty', 'zone', 'code', 'type', 'pitch_type',
#        'event_num', 'b_score', 'ab_id', 'b_count', 's_count', 'outs',
#        'pitch_num', 'on_1b', 'on_2b', 'on_3b', 'batter_id', 'event', 'g_id',
#        'inning', 'o', 'p_score', 'p_throws', 'pitcher_id', 'stand', 'top'],
#       dtype='object')

# %%
df = df[df['pitcher_id'] == 453286]

# %%
df
# Out:
#             px     pz  start_speed  end_speed    spin_rate     spin_dir  \
# 2407    -1.598  1.869         90.6       82.8     2704.451      235.379
# 2408    -0.909  2.487         93.5       85.0      2536.46      221.465
# 2409    -1.585  2.934         94.9       86.6     2546.016      220.551
# 2410     0.364  0.245         86.6       79.9       1628.2      245.895
# 2411    -1.927  4.250         94.0       85.7     2040.141      229.179
# ...        ...    ...          ...        ...          ...          ...
# 3578275 -0.530  2.740         79.1       73.0  placeholder  placeholder
# 3578276  1.390  0.800         84.8       78.5  placeholder  placeholder
# 3578277 -0.120  2.180         97.4       89.3  placeholder  placeholder
# 3578278  0.650  1.460         84.4       77.9  placeholder  placeholder
# 3578279  0.620  2.780         92.7       85.2  placeholder  placeholder
#
#          break_angle  break_length  break_y      ax  ...  batter_id   event  \
# ...

# %%
df = pd.merge(df,pd.concat([pd.read_csv('data/games.csv'),pd.read_csv('data/2019_games.csv')]),on='g_id')

# %%
df
# Out:
#           px     pz  start_speed  end_speed    spin_rate     spin_dir  \
# 0     -1.598  1.869         90.6       82.8     2704.451      235.379
# 1     -0.909  2.487         93.5       85.0      2536.46      221.465
# 2     -1.585  2.934         94.9       86.6     2546.016      220.551
# 3      0.364  0.245         86.6       79.9       1628.2      245.895
# 4     -1.927  4.250         94.0       85.7     2040.141      229.179
# ...      ...    ...          ...        ...          ...          ...
# 16307 -0.530  2.740         79.1       73.0  placeholder  placeholder
# 16308  1.390  0.800         84.8       78.5  placeholder  placeholder
# 16309 -0.120  2.180         97.4       89.3  placeholder  placeholder
# 16310  0.650  1.460         84.4       77.9  placeholder  placeholder
# 16311  0.620  2.780         92.7       85.2  placeholder  placeholder
#
#        break_angle  break_length  break_y      ax  ...  home_team  start_time  \
# ...

# %%
df.columns
# Out:
# Index(['px', 'pz', 'start_speed', 'end_speed', 'spin_rate', 'spin_dir',
#        'break_angle', 'break_length', 'break_y', 'ax', 'ay', 'az', 'sz_bot',
#        'sz_top', 'type_confidence', 'vx0', 'vy0', 'vz0', 'x', 'x0', 'y', 'y0',
#        'z0', 'pfx_x', 'pfx_z', 'nasty', 'zone', 'code', 'type', 'pitch_type',
#        'event_num', 'b_score', 'ab_id', 'b_count', 's_count', 'outs',
#        'pitch_num', 'on_1b', 'on_2b', 'on_3b', 'batter_id', 'event', 'g_id',
#        'inning', 'o', 'p_score', 'p_throws', 'pitcher_id', 'stand', 'top',
#        'attendance', 'away_final_score', 'away_team', 'date', 'elapsed_time',
#        'home_final_score', 'home_team', 'start_time', 'umpire_1B', 'umpire_2B',
#        'umpire_3B', 'umpire_HP', 'venue_name', 'weather', 'wind', 'delay'],
#       dtype='object')

# %%
df[['batter_id','date']].tail(5)
# Out:
#        batter_id        date
# 16307     664068  2019-09-24
# 16308     664068  2019-09-24
# 16309     664068  2019-09-24
# 16310     664068  2019-09-24
# 16311     656514  2019-09-24

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16312 entries, 0 to 16311
# Data columns (total 66 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   px                16249 non-null  float64
#  1   pz                16249 non-null  float64
#  2   start_speed       16249 non-null  float64
#  3   end_speed         16249 non-null  float64
#  4   spin_rate         16249 non-null  object
#  5   spin_dir          16249 non-null  object
#  6   break_angle       16249 non-null  float64
#  7   break_length      16249 non-null  float64
#  8   break_y           16249 non-null  float64
#  9   ax                16249 non-null  float64
#  10  ay                16249 non-null  float64
#  11  az                16249 non-null  float64
#  12  sz_bot            16296 non-null  float64
#  13  sz_top            16296 non-null  float64
#  14  type_confidence   16249 non-null  object
#  15  vx0               16249 non-null  float64
# ...

# %%
df
# Out:
#           px     pz  start_speed  end_speed    spin_rate     spin_dir  \
# 0     -1.598  1.869         90.6       82.8     2704.451      235.379
# 1     -0.909  2.487         93.5       85.0      2536.46      221.465
# 2     -1.585  2.934         94.9       86.6     2546.016      220.551
# 3      0.364  0.245         86.6       79.9       1628.2      245.895
# 4     -1.927  4.250         94.0       85.7     2040.141      229.179
# ...      ...    ...          ...        ...          ...          ...
# 16307 -0.530  2.740         79.1       73.0  placeholder  placeholder
# 16308  1.390  0.800         84.8       78.5  placeholder  placeholder
# 16309 -0.120  2.180         97.4       89.3  placeholder  placeholder
# 16310  0.650  1.460         84.4       77.9  placeholder  placeholder
# 16311  0.620  2.780         92.7       85.2  placeholder  placeholder
#
#        break_angle  break_length  break_y      ax  ...  home_team  start_time  \
# ...

# %%
df['year'] = df['g_id'].astype('string').map(lambda x : x[:4]).astype('int')

# %%
df['year']
# Out:
# 0        2015
# 1        2015
# 2        2015
# 3        2015
# 4        2015
#          ...
# 16307    2019
# 16308    2019
# 16309    2019
# 16310    2019
# 16311    2019
# Name: year, Length: 16312, dtype: int64

# %%
df.groupby(['year','pitch_type']).count()
# Out:
#                    px    pz  start_speed  end_speed  spin_rate  spin_dir  \
# year pitch_type
# 2015 CH           440   440          440        440        440       440
#      CU           271   271          271        271        271       271
#      FC            55    55           55         55         55        55
#      FF          1988  1988         1988       1988       1988      1988
#      SL           598   598          598        598        598       598
# 2016 CH           427   427          427        427        427       427
#      CU           287   287          287        287        287       287
#      FC            61    61           61         61         61        61
#      FF          1968  1968         1968       1968       1968      1968
#      SL           811   811          811        811        811       811
#      UN             1     1            1          1          1         1
# 2017 CH           441   441          441        441        441       441
# ...

# %%
#done
df.to_csv('data/scherzer.csv')

# %%
df.groupby(['pitch_type']).count()
# Out:
#               px    pz  start_speed  end_speed  spin_rate  spin_dir  \
# pitch_type
# CH          2257  2257         2257       2257       2257      2257
# CU          1330  1330         1330       1330       1330      1330
# FC           902   902          902        902        902       902
# FF          8458  8458         8458       8458       8458      8458
# FT            89    89           89         89         89        89
# SL          3212  3212         3212       3212       3212      3212
# UN             1     1            1          1          1         1
#
#             break_angle  break_length  break_y    ax  ...  start_time  \
# pitch_type                                            ...
# CH                 2257          2257     2257  2257  ...        1856
# CU                 1330          1330     1330  1330  ...        1090
# FC                  902           902      902   902  ...         688
# ...

# %%
#df= df[df['pitch_type'].notnull()]

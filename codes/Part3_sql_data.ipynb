# %% [markdown]
# ## Completed
# * Data assembling
#
# ## To do
# * SQL database
# * Data Cleaning

# %%
import pandas as pd

# %%
import sqlite3
from sqlalchemy import create_engine
from sqlalchemy import inspect

# %%
sqlite3.connect('mlb_2015_2019.db')

# %%
engine = create_engine('sqlite:///mlb_2015_2019.db')

# %%
df = pd.read_csv('data/scherzer.csv')
df.to_sql('scherzer',con=engine)
# Out:
# /opt/anaconda3/envs/metis/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (19,21,50) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df
# Out:
#        Unnamed: 0     px     pz  start_speed  end_speed  spin_rate  spin_dir  \
# 0               0 -1.598  1.869         90.6       82.8   2704.451   235.379
# 1               1 -0.909  2.487         93.5       85.0   2536.460   221.465
# 2               2 -1.585  2.934         94.9       86.6   2546.016   220.551
# 3               3  0.364  0.245         86.6       79.9   1628.200   245.895
# 4               4 -1.927  4.250         94.0       85.7   2040.141   229.179
# ...           ...    ...    ...          ...        ...        ...       ...
# 16307       16307 -0.530  2.740         79.1       73.0   2818.000       NaN
# 16308       16308  1.390  0.800         84.8       78.5   2295.000       NaN
# 16309       16309 -0.120  2.180         97.4       89.3   2465.000       NaN
# 16310       16310  0.650  1.460         84.4       77.9   1494.000       NaN
# 16311       16311  0.620  2.780         92.7       85.2   2299.000       NaN
#
# ...

# %%
df['year'] = df['g_id'].astype('string').map(lambda x : x[:4]).astype('int')

# %%
df['year']
# Out:
# 0        2015
# 1        2015
# 2        2015
# 3        2015
# 4        2015
#          ...
# 16307    2019
# 16308    2019
# 16309    2019
# 16310    2019
# 16311    2019
# Name: year, Length: 16312, dtype: int64

# %%
df.groupby(['year','pitch_type']).count()
# Out:
#                    px    pz  start_speed  end_speed  spin_rate  spin_dir  \
# year pitch_type
# 2015 CH           440   440          440        440        440       440
#      CU           271   271          271        271        271       271
#      FC            55    55           55         55         55        55
#      FF          1988  1988         1988       1988       1988      1988
#      SL           598   598          598        598        598       598
# 2016 CH           427   427          427        427        427       427
#      CU           287   287          287        287        287       287
#      FC            61    61           61         61         61        61
#      FF          1968  1968         1968       1968       1968      1968
#      SL           811   811          811        811        811       811
#      UN             1     1            1          1          1         1
# 2017 CH           441   441          441        441        441       441
# ...

# %%
df.groupby(['pitch_type']).count()
# Out:
#               px    pz  start_speed  end_speed  spin_rate  spin_dir  \
# pitch_type
# CH          2257  2257         2257       2257       2257      2257
# CU          1330  1330         1330       1330       1330      1330
# FC           902   902          902        902        902       902
# FF          8458  8458         8458       8458       8458      8458
# FT            89    89           89         89         89        89
# SL          3212  3212         3212       3212       3212      3212
# UN             1     1            1          1          1         1
#
#             break_angle  break_length  break_y    ax  ...  start_time  \
# pitch_type                                            ...
# CH                 2257          2257     2257  2257  ...        1856
# CU                 1330          1330     1330  1330  ...        1090
# FC                  902           902      902   902  ...         688
# ...
